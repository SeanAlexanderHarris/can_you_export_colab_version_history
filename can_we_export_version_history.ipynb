# %% [markdown]
# <a href="https://colab.research.google.com/github/SeanAlexanderHarris/can_you_export_colab_version_history/blob/main/can_we_export_version_history.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Random German Name Generator
#
# This notebook will select and display a random German name from a list of 20 names.

# %% [markdown]
# ### Random Alien Name Generator
#
# This notebook will select and display a random made-up alien name from a list of 20 names.

# %%
import random

# List of 20 made-up alien names
alien_names = [
    "Zylar", "Kaelen", "Xylo", "Lyra-7", "Grakon", "Seraph", "Vortex", "Nylos", "Astraea", "Ragnar",
    "Elara-9", "Dro'tharr", "Quill", "Zoria", "Blorp", "Nyx", "Kael", "Zypher", "Stryx", "Vex"
]

# Select a random name from the list
random_name = random.choice(alien_names)

# Display the randomly selected name
print(f"Randomly generated Alien name: {random_name}")

# %%
import random

# List of 20 German names
german_names = [
    "Anna", "Max", "Sophie", "Felix", "Mia", "Luca", "Hannah", "Paul", "Lena", "Jonas",
    "Emilia", "Leon", "Marie", "David", "Laura", "Noah", "Clara", "Ben", "Julia", "Tim"
]

# Select a random name from the list
random_name = random.choice(german_names)

# Display the randomly selected name
print(f"Randomly generated German name: {random_name}")

# %% [markdown]
# ### Random Spanish Name Generator
#
# This notebook will select and display a random Spanish name from a list of 20 names.

# %%
import random

# List of 20 Spanish names
spanish_names = [
    "Sofia", "Mateo", "Valentina", "Santiago", "Camila", "Sebastian", "Isabella", "Nicolas", "Valeria", "Daniel",
    "Mariana", "Alejandro", "Victoria", "Diego", "Luciana", "Samuel", "Gabriela", "Andres", "Catalina", "Ricardo"
]

# Select a random name from the list
random_name = random.choice(spanish_names);

# Display the randomly selected name
print(f"Randomly generated Spanish name: {random_name}")

# %% [markdown]
# ### Random French Name Generator
#
# This notebook will select and display a random French name from a list of 20 names.

# %%
import random

# List of 20 French names
french_names = [
    "Léa", "Louis", "Manon", "Gabriel", "Chloé", "Raphaël", "Emma", "Arthur", "Alice", "Hugo",
    "Inès", "Jules", "Camille", "Adam", "Sarah", "Lucas", "Eva", "Nathan", "Louise", "Tom"
]

# Select a random name from the list
random_name = random.choice(french_names)

# Display the randomly selected name
print(f"Randomly generated French name: {random_name}")
